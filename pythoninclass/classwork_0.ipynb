# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd

# %% [markdown]
# ### Importing from github

# %%
githubread = pd.read_csv('https://raw.githubusercontent.com/samishaikk/Sample-csv-file/refs/heads/main/synthetic_cognitive_ability_data.csv?token=GHSAT0AAAAAADOOG5ZMUBBOTLZWJOB3RPKO2IJQKZQ')
githubread
# Out:
#       memory_score  logic_score  attention_score  reaction_time  \
# 0         0.374540     0.950714         0.731994       0.598658
# 1         0.020584     0.969910         0.832443       0.212339
# 2         0.611853     0.139494         0.292145       0.366362
# 3         0.607545     0.170524         0.065052       0.948886
# 4         0.122038     0.495177         0.034389       0.909320
# ...            ...          ...              ...            ...
# 9995      0.108506     0.246123         0.403444       0.797405
# 9996      0.919552     0.807998         0.165067       0.490769
# 9997      0.089951     0.092531         0.769020       0.982755
# 9998      0.910525     0.853603         0.319290       0.355033
# 9999      0.783931     0.124664         0.931927       0.413441
#
#       visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# 0            0.156019        0.155995           0.058084          0.866176
# ...

# %%
githubread.columns
# Out:
# Index(['memory_score', 'logic_score', 'attention_score', 'reaction_time',
#        'visual_accuracy', 'verbal_fluency', 'emotional_control',
#        'processing_speed', 'multitasking', 'task_switching', 'reward'],
#       dtype='object')

# %%
githubread.head(10)
# Out:
#    memory_score  logic_score  attention_score  reaction_time  visual_accuracy  \
# 0      0.374540     0.950714         0.731994       0.598658         0.156019
# 1      0.020584     0.969910         0.832443       0.212339         0.181825
# 2      0.611853     0.139494         0.292145       0.366362         0.456070
# 3      0.607545     0.170524         0.065052       0.948886         0.965632
# 4      0.122038     0.495177         0.034389       0.909320         0.258780
# 5      0.969585     0.775133         0.939499       0.894827         0.597900
# 6      0.388677     0.271349         0.828738       0.356753         0.280935
# 7      0.772245     0.198716         0.005522       0.815461         0.706857
# 8      0.863103     0.623298         0.330898       0.063558         0.310982
# 9      0.119594     0.713245         0.760785       0.561277         0.770967
#
#    verbal_fluency  emotional_control  processing_speed  multitasking  \
# ...

# %%
githubread.tail(10)
# Out:
#       memory_score  logic_score  attention_score  reaction_time  \
# 9990      0.401063     0.515762         0.609962       0.299143
# 9991      0.512339     0.107088         0.472974       0.745254
# 9992      0.226069     0.263655         0.870089       0.743430
# 9993      0.457268     0.948661         0.643269       0.679363
# 9994      0.150233     0.022936         0.992158       0.647350
# 9995      0.108506     0.246123         0.403444       0.797405
# 9996      0.919552     0.807998         0.165067       0.490769
# 9997      0.089951     0.092531         0.769020       0.982755
# 9998      0.910525     0.853603         0.319290       0.355033
# 9999      0.783931     0.124664         0.931927       0.413441
#
#       visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# 9990         0.156733        0.635198           0.441912          0.057631
# 9991         0.132728        0.623587           0.177871          0.309092
# ...

# %% [markdown]
# ### Reading the excel file

# %%
excelfile = pd.read_excel("D:/AI COURSE/python/synthetic_cognitive_ability_data.xlsx")
excelfile
# Out:
#       memory_score  logic_score  attention_score  reaction_time  \
# 0         0.374540     0.950714         0.731994       0.598658
# 1         0.020584     0.969910         0.832443       0.212339
# 2         0.611853     0.139494         0.292145       0.366362
# 3         0.607545     0.170524         0.065052       0.948886
# 4         0.122038     0.495177         0.034389       0.909320
# ...            ...          ...              ...            ...
# 9995      0.108506     0.246123         0.403444       0.797405
# 9996      0.919552     0.807998         0.165067       0.490769
# 9997      0.089951     0.092531         0.769020       0.982755
# 9998      0.910525     0.853603         0.319290       0.355033
# 9999      0.783931     0.124664         0.931927       0.413441
#
#       visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# 0            0.156019        0.155995           0.058084          0.866176
# ...

# %%
print(excelfile.shape)  # (rows, columns)
# Out:
# (10000, 11)

# %%
print(excelfile.columns)
# Out:
# Index(['memory_score', 'logic_score', 'attention_score', 'reaction_time',
#        'visual_accuracy', 'verbal_fluency', 'emotional_control',
#        'processing_speed', 'multitasking', 'task_switching', 'reward'],
#       dtype='object')

# %%
excelfile.head
# Out:
# <bound method NDFrame.head of       memory_score  logic_score  attention_score  reaction_time  \
# 0         0.374540     0.950714         0.731994       0.598658
# 1         0.020584     0.969910         0.832443       0.212339
# 2         0.611853     0.139494         0.292145       0.366362
# 3         0.607545     0.170524         0.065052       0.948886
# 4         0.122038     0.495177         0.034389       0.909320
# ...            ...          ...              ...            ...
# 9995      0.108506     0.246123         0.403444       0.797405
# 9996      0.919552     0.807998         0.165067       0.490769
# 9997      0.089951     0.092531         0.769020       0.982755
# 9998      0.910525     0.853603         0.319290       0.355033
# 9999      0.783931     0.124664         0.931927       0.413441
#
#       visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# 0            0.156019        0.155995           0.058084          0.866176
# ...

# %%
excelfile.head(10)
# Out:
#    memory_score  logic_score  attention_score  reaction_time  visual_accuracy  \
# 0      0.374540     0.950714         0.731994       0.598658         0.156019
# 1      0.020584     0.969910         0.832443       0.212339         0.181825
# 2      0.611853     0.139494         0.292145       0.366362         0.456070
# 3      0.607545     0.170524         0.065052       0.948886         0.965632
# 4      0.122038     0.495177         0.034389       0.909320         0.258780
# 5      0.969585     0.775133         0.939499       0.894827         0.597900
# 6      0.388677     0.271349         0.828738       0.356753         0.280935
# 7      0.772245     0.198716         0.005522       0.815461         0.706857
# 8      0.863103     0.623298         0.330898       0.063558         0.310982
# 9      0.119594     0.713245         0.760785       0.561277         0.770967
#
#    verbal_fluency  emotional_control  processing_speed  multitasking  \
# ...

# %%
excelfile.tail(10)
# Out:
#       memory_score  logic_score  attention_score  reaction_time  \
# 9990      0.401063     0.515762         0.609962       0.299143
# 9991      0.512339     0.107088         0.472974       0.745254
# 9992      0.226069     0.263655         0.870089       0.743430
# 9993      0.457268     0.948661         0.643269       0.679363
# 9994      0.150233     0.022936         0.992158       0.647350
# 9995      0.108506     0.246123         0.403444       0.797405
# 9996      0.919552     0.807998         0.165067       0.490769
# 9997      0.089951     0.092531         0.769020       0.982755
# 9998      0.910525     0.853603         0.319290       0.355033
# 9999      0.783931     0.124664         0.931927       0.413441
#
#       visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# 9990         0.156733        0.635198           0.441912          0.057631
# 9991         0.132728        0.623587           0.177871          0.309092
# ...

# %%
excelfile.dtypes
# Out:
# memory_score         float64
# logic_score          float64
# attention_score      float64
# reaction_time        float64
# visual_accuracy      float64
# verbal_fluency       float64
# emotional_control    float64
# processing_speed     float64
# multitasking         float64
# task_switching       float64
# reward               float64
# dtype: object

# %%
excelfile.count
# Out:
# <bound method DataFrame.count of       memory_score  logic_score  attention_score  reaction_time  \
# 0         0.374540     0.950714         0.731994       0.598658
# 1         0.020584     0.969910         0.832443       0.212339
# 2         0.611853     0.139494         0.292145       0.366362
# 3         0.607545     0.170524         0.065052       0.948886
# 4         0.122038     0.495177         0.034389       0.909320
# ...            ...          ...              ...            ...
# 9995      0.108506     0.246123         0.403444       0.797405
# 9996      0.919552     0.807998         0.165067       0.490769
# 9997      0.089951     0.092531         0.769020       0.982755
# 9998      0.910525     0.853603         0.319290       0.355033
# 9999      0.783931     0.124664         0.931927       0.413441
#
#       visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# 0            0.156019        0.155995           0.058084          0.866176
# ...

# %%
excelfile.count()
# Out:
# memory_score         10000
# logic_score          10000
# attention_score      10000
# reaction_time        10000
# visual_accuracy      10000
# verbal_fluency       10000
# emotional_control    10000
# processing_speed     10000
# multitasking         10000
# task_switching       10000
# reward               10000
# dtype: int64

# %%
excelfile.count().sum()
# Out:
# np.int64(110000)

# %%
type(githubread)
# Out:
# pandas.core.frame.DataFrame

# %%
type(excelfile)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Reading the html file

# %%
githubread.to_html('samplehtml.html')

# %%
htmlread = pd.read_html('D:/AI COURSE/datamites/pythoninclass/samplehtml.html')
htmlread
# Out:
# [      Unnamed: 0  memory_score  logic_score  attention_score  reaction_time  \
#  0              0      0.374540     0.950714         0.731994       0.598658
#  1              1      0.020584     0.969910         0.832443       0.212339
#  2              2      0.611853     0.139494         0.292145       0.366362
#  3              3      0.607545     0.170524         0.065052       0.948886
#  4              4      0.122038     0.495177         0.034389       0.909320
#  ...          ...           ...          ...              ...            ...
#  9995        9995      0.108506     0.246123         0.403444       0.797405
#  9996        9996      0.919552     0.807998         0.165067       0.490769
#  9997        9997      0.089951     0.092531         0.769020       0.982755
#  9998        9998      0.910525     0.853603         0.319290       0.355033
#  9999        9999      0.783931     0.124664         0.931927       0.413441
#
# ...

# %%
firsttable = htmlread[0]
firsttable
# Out:
#       Unnamed: 0  memory_score  logic_score  attention_score  reaction_time  \
# 0              0      0.374540     0.950714         0.731994       0.598658
# 1              1      0.020584     0.969910         0.832443       0.212339
# 2              2      0.611853     0.139494         0.292145       0.366362
# 3              3      0.607545     0.170524         0.065052       0.948886
# 4              4      0.122038     0.495177         0.034389       0.909320
# ...          ...           ...          ...              ...            ...
# 9995        9995      0.108506     0.246123         0.403444       0.797405
# 9996        9996      0.919552     0.807998         0.165067       0.490769
# 9997        9997      0.089951     0.092531         0.769020       0.982755
# 9998        9998      0.910525     0.853603         0.319290       0.355033
# 9999        9999      0.783931     0.124664         0.931927       0.413441
#
# ...

# %%
firsttable.head(10)
# Out:
#    Unnamed: 0  memory_score  logic_score  attention_score  reaction_time  \
# 0           0      0.374540     0.950714         0.731994       0.598658
# 1           1      0.020584     0.969910         0.832443       0.212339
# 2           2      0.611853     0.139494         0.292145       0.366362
# 3           3      0.607545     0.170524         0.065052       0.948886
# 4           4      0.122038     0.495177         0.034389       0.909320
# 5           5      0.969585     0.775133         0.939499       0.894827
# 6           6      0.388677     0.271349         0.828738       0.356753
# 7           7      0.772245     0.198716         0.005522       0.815461
# 8           8      0.863103     0.623298         0.330898       0.063558
# 9           9      0.119594     0.713245         0.760785       0.561277
#
#    visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# 0         0.156019        0.155995           0.058084          0.866176
# ...

# %%
firsttable.tail(10)
# Out:
#       Unnamed: 0  memory_score  logic_score  attention_score  reaction_time  \
# 9990        9990      0.401063     0.515762         0.609962       0.299143
# 9991        9991      0.512339     0.107088         0.472974       0.745254
# 9992        9992      0.226069     0.263655         0.870089       0.743430
# 9993        9993      0.457268     0.948661         0.643269       0.679363
# 9994        9994      0.150233     0.022936         0.992158       0.647350
# 9995        9995      0.108506     0.246123         0.403444       0.797405
# 9996        9996      0.919552     0.807998         0.165067       0.490769
# 9997        9997      0.089951     0.092531         0.769020       0.982755
# 9998        9998      0.910525     0.853603         0.319290       0.355033
# 9999        9999      0.783931     0.124664         0.931927       0.413441
#
#       visual_accuracy  verbal_fluency  emotional_control  processing_speed  \
# ...

# %%
print(firsttable.shape)
# Out:
# (10000, 12)

# %%
print(firsttable.columns)
# Out:
# Index(['Unnamed: 0', 'memory_score', 'logic_score', 'attention_score',
#        'reaction_time', 'visual_accuracy', 'verbal_fluency',
#        'emotional_control', 'processing_speed', 'multitasking',
#        'task_switching', 'reward'],
#       dtype='object')

# %%
print(firsttable.dtypes)
# Out:
# Unnamed: 0             int64
# memory_score         float64
# logic_score          float64
# attention_score      float64
# reaction_time        float64
# visual_accuracy      float64
# verbal_fluency       float64
# emotional_control    float64
# processing_speed     float64
# multitasking         float64
# task_switching       float64
# reward               float64
# dtype: object

# %% [markdown]
# ### Converting series into df

# %%
sampleseries = pd.Series(["apple",'banana','pomegranate','guava','grapes'])
sampleseries
# Out:
# 0          apple
# 1         banana
# 2    pomegranate
# 3          guava
# 4         grapes
# dtype: object

# %%
pd.DataFrame(sampleseries)
# Out:
#              0
# 0        apple
# 1       banana
# 2  pomegranate
# 3        guava
# 4       grapes

# %% [markdown]
# ### converting list into series

# %%
samplelist = [[1,2,3],[4,5,6],[7,8,9]]
samplelist
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
pd.Series(samplelist)
# Out:
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# 2    [7, 8, 9]
# dtype: object

# %% [markdown]
# ### converting dataframe to csv file

# %%
sampledf = pd.DataFrame({
    'Name': ['sami', 'kohli', 'abd'],
    'Age': [25, 30, 33]
})

# %%
sampledf
# Out:
#     Name  Age
# 0   sami   25
# 1  kohli   30
# 2    abd   33

# %%
sampledf.index.name = 'Id'

# %%
sampledf.to_csv('df_tocsv.csv')

# %%
sampledf
# Out:
#      Name  Age
# Id
# 0    sami   25
# 1   kohli   30
# 2     abd   33
