# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# #### Collinearity
#
# - It is the relationsihp between independent features among each other.
# - In LR, there should be colinearity.

# %%
# df.corr()

# %% [markdown]
# - Since disp and cyl have a high colinearity we will drop them.

# %%
# df.drop(columns=['disp','cyl'], inplace=True)

# %%
# df.head()

# %%
# X = df.iloc[:,1:]
# y = df.mpg

# %%
# Train-test split

# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
# X_train.shape

# %%
# X_test.shape

# %%
# y_train.shape

# %%
# y_test.shape

# %%
# model creation

'''
from sklearn.linear_model import LinearRegression
model = Linear Regression()
model.fit(X_train,y_train)
'''
# Out:
# '\nfrom sklearn.linear_model import LinearRegression\nmodel = Linear Regression()\nmodel.fit(X_train,y_train)\n'

# %%
# coef = model.coef_

# %%
# model.intercept_

# %%
# X_train.head()

# %%
# inputs = [23,3.55,4.044,2,2,3]
# coef[0] * inputs[0] + coef[1]*inputs[1]+coef[2]*inputs[2]+
# coef[3] * inputs[3]+coef[4]*inputs[4]+coef[5]*inputs[5]+model.intercept_

# %%
# model.predict([inputs])

# %%
# y_pred = model.predict(X_test)
# y_pred

# %%
# y_test

# %%
# model evaluation
# from sklearn.metrics import r2_score
# r2_score(y_test,y_pred)
